# %% [markdown]
# <span style="font-size:20px;">P5 : Segmentation des clients d’un Site E-Commerce

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%202023-03-07%20091224.png](attachment:Capture%20d%E2%80%99%C3%A9cran%202023-03-07%20091224.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Importation-des-data-sets" data-toc-modified-id="Importation-des-data-sets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importation des data sets</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Chargement" data-toc-modified-id="Chargement-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Chargement</a></span><ul class="toc-item"><li><span><a href="#Nombre-de-lignes-et-colonnes" data-toc-modified-id="Nombre-de-lignes-et-colonnes-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Nombre de lignes et colonnes</a></span></li><li><span><a href="#Nom-des-DataFrame" data-toc-modified-id="Nom-des-DataFrame-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Nom des DataFrame</a></span></li></ul></li><li><span><a href="#Customers" data-toc-modified-id="Customers-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Customers</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Analyse graphiques</a></span><ul class="toc-item"><li><span><a href="#Nombre-de-consommateur-par-Etat" data-toc-modified-id="Nombre-de-consommateur-par-Etat-4.2.2.1"><span class="toc-item-num">4.2.2.1&nbsp;&nbsp;</span>Nombre de consommateur par Etat</a></span></li><li><span><a href="#Nombre-de-consommateur-par-ville" data-toc-modified-id="Nombre-de-consommateur-par-ville-4.2.2.2"><span class="toc-item-num">4.2.2.2&nbsp;&nbsp;</span>Nombre de consommateur par ville</a></span></li></ul></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Geolocation" data-toc-modified-id="Geolocation-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Geolocation</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Analyse graphiques</a></span><ul class="toc-item"><li><span><a href="#Nombre-de-clients-par-Etat" data-toc-modified-id="Nombre-de-clients-par-Etat-4.3.2.1"><span class="toc-item-num">4.3.2.1&nbsp;&nbsp;</span>Nombre de clients par Etat</a></span></li></ul></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Order-payments" data-toc-modified-id="Order-payments-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Order payments</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span><ul class="toc-item"><li><span><a href="#payment_sequential" data-toc-modified-id="payment_sequential-4.4.1.1"><span class="toc-item-num">4.4.1.1&nbsp;&nbsp;</span>payment_sequential</a></span></li><li><span><a href="#payment_installments" data-toc-modified-id="payment_installments-4.4.1.2"><span class="toc-item-num">4.4.1.2&nbsp;&nbsp;</span>payment_installments</a></span></li></ul></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Analyse graphiques</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Orders" data-toc-modified-id="Orders-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Orders</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Missing-values" data-toc-modified-id="Missing-values-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Missing values</a></span><ul class="toc-item"><li><span><a href="#order_delivered_customer_date" data-toc-modified-id="order_delivered_customer_date-4.5.2.1"><span class="toc-item-num">4.5.2.1&nbsp;&nbsp;</span>order_delivered_customer_date</a></span></li></ul></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Analyse graphiques</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Order_items" data-toc-modified-id="Order_items-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Order_items</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Analyse graphiques</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Order_reviews" data-toc-modified-id="Order_reviews-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Order_reviews</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Analyse-graphiques" data-toc-modified-id="Analyse-graphiques-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Analyse graphiques</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Products" data-toc-modified-id="Products-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Products</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.8.2"><span class="toc-item-num">4.8.2&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Sellers" data-toc-modified-id="Sellers-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Sellers</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.9.1"><span class="toc-item-num">4.9.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.9.2"><span class="toc-item-num">4.9.2&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li><li><span><a href="#Category-Name-Translation" data-toc-modified-id="Category-Name-Translation-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Category Name Translation</a></span><ul class="toc-item"><li><span><a href="#Analyse-des-colonnes" data-toc-modified-id="Analyse-des-colonnes-4.10.1"><span class="toc-item-num">4.10.1&nbsp;&nbsp;</span>Analyse des colonnes</a></span></li><li><span><a href="#Save-CSV" data-toc-modified-id="Save-CSV-4.10.2"><span class="toc-item-num">4.10.2&nbsp;&nbsp;</span>Save CSV</a></span></li></ul></li></ul></li><li><span><a href="#Merge" data-toc-modified-id="Merge-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Merge</a></span><ul class="toc-item"><li><span><a href="#Importation-des-fichier" data-toc-modified-id="Importation-des-fichier-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Importation des fichier</a></span></li><li><span><a href="#transformed_orders-+-transformed_order_items" data-toc-modified-id="transformed_orders-+-transformed_order_items-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>transformed_orders + transformed_order_items</a></span></li><li><span><a href="#orders_complet-+-transformed_customers" data-toc-modified-id="orders_complet-+-transformed_customers-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>orders_complet + transformed_customers</a></span></li><li><span><a href="#transformed_products-+-transformed_product_category_name" data-toc-modified-id="transformed_products-+-transformed_product_category_name-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>transformed_products + transformed_product_category_name</a></span></li><li><span><a href="#customers_orders-+-products_complet" data-toc-modified-id="customers_orders-+-products_complet-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>customers_orders + products_complet</a></span></li><li><span><a href="#order_payments" data-toc-modified-id="order_payments-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>order_payments</a></span></li><li><span><a href="#customers_orders-+-order_payments" data-toc-modified-id="customers_orders-+-order_payments-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>customers_orders + order_payments</a></span></li><li><span><a href="#customers_orders_payments-+-transformed_order_reviews" data-toc-modified-id="customers_orders_payments-+-transformed_order_reviews-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>customers_orders_payments + transformed_order_reviews</a></span><ul class="toc-item"><li><span><a href="#Analyses-graphiques" data-toc-modified-id="Analyses-graphiques-5.8.1"><span class="toc-item-num">5.8.1&nbsp;&nbsp;</span>Analyses graphiques</a></span></li></ul></li><li><span><a href="#Save-CSV-:-cleaned_customers_orders_payments_dataset" data-toc-modified-id="Save-CSV-:-cleaned_customers_orders_payments_dataset-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Save CSV : cleaned_customers_orders_payments_dataset</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports

# %% [markdown]
# Importons dans un premier temps l'ensemble des librairies qui vont nous servir durant l'entièreté de ce Notebook :

# %%
# builtin
import os
# datetime 
import datetime as dt

#data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#feature engineering
from sklearn.feature_selection import mutual_info_regression

#Afficher toutes le colonnes du data frame : 
pd.set_option('display.max_columns', 80)
pd.set_option("display.max_row", 80)

sns.set(style='whitegrid', palette='muted', color_codes=True)
print('OK!! ')
# Out:
# OK!!

# %% [markdown]
# # Importation des data sets

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00_data.ipynb',
#  '01_RFM-Copy1.ipynb',
#  '01_RFM.ipynb',
#  'corrige.py',
#  'corrige.py.zip',
#  'data',
#  'EDA_AutoViz.ipynb',
#  'figures',
#  'Maintenance_.ipynb',
#  'Untitled.ipynb',
#  'Versions.ipynb']

# %% [markdown]
# # Functions

# %%
# Fonction qui return une description du data set df

def rapport_df(df): 
    
    #Valeurs manquantes
    def check_missing(df):
    # Total NaN/Features: 
        total = df.isnull().sum().sort_values(ascending = False) 
        # Pourcentage NaN/Features:
        percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
        # Sortie sous forme d'un data frame: 
        df_missing  = pd.concat([total, percent], axis=1, keys=['Total_NAN', 'Percent'])
        return df_missing

    missing_data= check_missing(df)
    liste_features_vides = list((missing_data[missing_data.Percent == 100 ]).index)
    nombre_col_vides = len(liste_features_vides)
    
    # calcul du taux de valeurs manquantes : 
    taux_remplissage = (df.notnull().sum().sum()/np.product(df.shape)) * 100
    

    print('Le Taux de remplissage total est égal à :', taux_remplissage, "%")   
    print('Le Nombre de features vides est égal à :', nombre_col_vides, "Features")
    print('Les Features vides sont :', liste_features_vides)
#     print('Le Nombre de Valeurs en double est égal à :', valeurDoubl, "valeurs")
    print()
    print("*****Nombre de catégorie features catégorielles******\n")
    # Nombre de catégories par varaible qualitatives
    for col in df.select_dtypes('object'):
        print(f'{col :-<50} {df[col].unique().size}')

# %%
# Code Copié : https://github.com/samirhinojosa/OC-P4-consumption-needs-of-buildings/blob/master/analysis_notebook.ipynb

# Distribution initiale et transformées des colonnes : columns

def plot_distribution(df, columns):
    # Copie du df
    df_ = df.copy()
    
    # Transformation Log, Log2, et Log10
    for col in columns:
        df_[col + "_log"] = np.log(df_[col] + 1)
        df_[col + "_log2"] = np.log2(df_[col] + 1)
        df_[col + "_log10"] = np.log10(df_[col] + 1)

    for var in columns:

        # We are going to work only with the rows without missing-values for the features
        df_subset = pd.DataFrame(df_[df_[[col]].notnull().all(axis=1)]).reset_index(drop=True)

        var_cols = [var + "", var + "_log", var + "_log2", var + "_log10"]

        fig = plt.figure(constrained_layout=True, figsize=[15,10])
        fig.suptitle(var, size=25, fontweight="bold", y=1.05)
        spec = fig.add_gridspec(ncols=2, nrows=4, width_ratios=[1,1], height_ratios=[0.3,2,0.3,2])

        # to cycle through the columns 
        col_boxplot, col_histplot = 0, 0

        for i in range(4):

            for j in range(2):

                if i % 2 == 0:

                    if col_boxplot > len(var_cols) - 1:
                        break

                    ax_box = fig.add_subplot(spec[i, j])
                    boxplot = sns.boxplot(data=df_subset, x=var_cols[col_boxplot], ax=ax_box)

                    # Remove x axis name for the boxplot
                    ax_box.set(xlabel="", xticks=[])
                    ax_box.set(yticks=[])

                    boxplot.set_title(var_cols[col_boxplot], fontdict={ "fontsize": 15, "fontweight": "bold" })

                    col_boxplot += 1

                elif i % 2 != 0:

                    if col_histplot > len(columns) - 1:
                        break

                    ax_hist = fig.add_subplot(spec[i, j])
                    sns.histplot(data=df_subset, x=var_cols[col_histplot], bins=100,  kde=True,  ax=ax_hist)
                    ax_hist.set(xlabel=var_cols[col_histplot])

                    col_histplot += 1

    #     plt.savefig("figures/transformation-" + var + ".png", transparent=True, bbox_inches='tight', dpi=200)
        sns.despine(fig)  
        plt.show()

# %%
def save_transformed_df(df, path, filename, columns_to_save):
    
    # Fonction pour Save un df, dans le dossier : path avec le nom : filename, 
    # avec sélection des colonnes : columns_to_save
    
    df[columns_to_save].to_csv(path + filename, index=False)

# %% [markdown]
# # Data

# %% [markdown]
# <span style="font-size:16px;">Les données sont Téléchargeables en suivant le lien suivant  : [Les données](https://www.kaggle.com/olistbr/brazilian-ecommerce)

# %% [markdown]
# <span style="font-size:16px;">Dance ce qui suit nous téléchargerons les data sets de la base de données.

# %%
os.listdir("data/source")
# Out:
# ['olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv']

# %% [markdown]
# ## Chargement

# %% [markdown]
# ### Nombre de lignes et colonnes

# %%
# Liste des dataframes avec l'extension type fichier
name_datasets = ['olist_customers_dataset.csv',
                 'olist_geolocation_dataset.csv',
                 'olist_orders_dataset.csv',
                 'olist_order_items_dataset.csv',
                 'olist_order_payments_dataset.csv',
                 'olist_order_reviews_dataset.csv',
                 'olist_products_dataset.csv',
                 'olist_sellers_dataset.csv',
                 'product_category_name_translation.csv']

# %%
path = "./data/source/"

# Liste des données à afficher : 
summary_list = []
for i, name in enumerate(name_datasets):
    df = pd.read_csv(path + name_datasets[i])
    rows, cols = df.shape
    summary = {'DataFrame': name, 'Lignes': rows, 'Colonnes': cols}
    summary_list.append(summary)
summary_df = pd.DataFrame(summary_list)
summary_df
# Out:
#                                DataFrame   Lignes  Colonnes
# 0            olist_customers_dataset.csv    99441         5
# 1          olist_geolocation_dataset.csv  1000163         5
# 2               olist_orders_dataset.csv    99441         8
# 3          olist_order_items_dataset.csv   112650         7
# 4       olist_order_payments_dataset.csv   103886         5
# 5        olist_order_reviews_dataset.csv    99224         7
# 6             olist_products_dataset.csv    32951         9
# 7              olist_sellers_dataset.csv     3095         4
# 8  product_category_name_translation.csv       71         2

# %%
# transformed_customers_dataset
df = summary_df
path = "./data/summary/"
filename = "summary_df.csv"
columns_to_save = ['DataFrame', 'Lignes', 'Colonnes']

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ### Nom des DataFrame

# %% [markdown]
# Récupération des nom des data frame automatiquement

# %%
# Récupération des nom des ifchiers : 
name_datasets = ['olist_customers_dataset.csv',
                 'olist_geolocation_dataset.csv',
                 'olist_orders_dataset.csv',
                 'olist_order_items_dataset.csv',
                 'olist_order_payments_dataset.csv',
                 'olist_order_reviews_dataset.csv',
                 'olist_products_dataset.csv',
                 'olist_sellers_dataset.csv',
#                  'product_category_name_translation.csv'
                ]
# Récupération des noms de datasets
# initializing substrings
sub1 = "olist"
sub2 = "_dataset.csv"
idx1 = 0
idx2 = 0
liste_name = []
for name in name_datasets:
    # getting index of substrings
    name = str(name)
    idx1 = name.index(sub1)
    idx2 = name.index(sub2)
    res = ''
    for idx in range(idx1 + len(sub1) + 1, idx2):
        res = res + name[idx]
    #printing result
    name_= str(res)
    liste_name.append(name_)

# %%
liste_name
# Out:
# ['customers',
#  'geolocation',
#  'orders',
#  'order_items',
#  'order_payments',
#  'order_reviews',
#  'products',
#  'sellers']

# %%
# Importation et nommage des data sets
path = "./data/source/"
for i, name in enumerate(liste_name):
    exec(f"{name} = pd.read_csv(path + name_datasets[i])")

# %%
# Code copié : pour afficher rapidement les informations des data sets: 

datasets = [customers, geolocation, orders, order_items, order_payments, order_reviews, products, sellers]


data_summary = pd.DataFrame({},)
data_summary['datasets']= liste_name
data_summary['columns'] = [', '.join([col for col, null in data.isnull().sum().items() ]) for data in datasets]
data_summary['total_rows']= [data.shape[0] for data in datasets]
data_summary['total_cols']= [data.shape[1] for data in datasets]
data_summary['total_duplicate']= [len(data[data.duplicated()]) for data in datasets]
data_summary['total_null']= [data.isnull().sum().sum() for data in datasets]
data_summary['null_cols'] = [', '.join([col for col, null in data.isnull().sum().items() if null > 0]) for data in datasets]
data_summary.style.background_gradient(cmap='YlGnBu')
# Out:
# <style type="text/css">
# #T_7e434_row0_col2, #T_7e434_row2_col2, #T_7e434_row5_col2 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_7e434_row0_col3, #T_7e434_row1_col3, #T_7e434_row4_col3 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_7e434_row0_col4, #T_7e434_row0_col5, #T_7e434_row1_col5, #T_7e434_row2_col4, #T_7e434_row3_col4, #T_7e434_row3_col5, #T_7e434_row4_col4, #T_7e434_row4_col5, #T_7e434_row5_col4, #T_7e434_row6_col4, #T_7e434_row7_col2, #T_7e434_row7_col3, #T_7e434_row7_col4, #T_7e434_row7_col5 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_7e434_row1_col2, #T_7e434_row1_col4, #T_7e434_row5_col5, #T_7e434_row6_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_7e434_row2_col3 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_7e434_row2_col5 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_7e434_row3_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# ...

# %%
# Product_category_name
path = "./data/source/"
filename = "product_category_name_translation.csv"
product_category_name = pd.read_csv(path+filename)

# %% [markdown]
# ## Customers

# %% [markdown]
# cutomers : relié à geolocation (via zip_code_prefix) et orders (via customer_id)
#
# Le dataset cutomers est composé de 5 colonnes :
# - customer_id : identifiant client lors de l'achat d'un produit
# - cutomer_unique_id : identifiant unique du client lors de la connexion sur le site
# - customer_zip_code_prefix : code postal du consommateur
# - customer_state : ville consommateur

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.shape
# Out:
# (99441, 5)

# %% [markdown]
# Nombre total de consommateur = 96096

# %%
rapport_df(customers)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# customer_id--------------------------------------- 99441
# customer_unique_id-------------------------------- 96096
# customer_city------------------------------------- 4119
# customer_state------------------------------------ 27

# %%
# Information de notre data frame 
customers.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 29.6 MB

# %%
customers.isna().mean().sort_values(ascending=False) * 100
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# Regardons les colonnes en détail

# %% [markdown]
# **customer_id**

# %%
customers.duplicated(subset='customer_id').sum()
# Out:
# 0

# %% [markdown]
# **customer_unique_id**

# %%
customers.duplicated(subset='customer_unique_id').sum()
# Out:
# 3345

# %% [markdown]
# Répartirion du nombre de consommateurs selon l'Etat

# %%
customers["customer_state"].value_counts(normalize=True)
# Out:
# SP    0.419807
# RJ    0.129242
# MG    0.117004
# RS    0.054967
# PR    0.050734
# SC    0.036574
# BA    0.033990
# DF    0.021520
# ES    0.020444
# GO    0.020314
# PE    0.016613
# CE    0.013435
# PA    0.009805
# MT    0.009121
# MA    0.007512
# MS    0.007190
# PB    0.005390
# PI    0.004978
# RN    0.004877
# AL    0.004153
# SE    0.003520
# TO    0.002816
# RO    0.002544
# AM    0.001488
# AC    0.000815
# AP    0.000684
# RR    0.000463
# Name: customer_state, dtype: float64

# %% [markdown]
# ### Analyse graphiques

# %% [markdown]
# #### Nombre de consommateur par Etat

# %%
df_ = customers.drop_duplicates(subset=["customer_unique_id"], keep="last")
df_ = df_.groupby('customer_state')[['customer_unique_id']].count().reset_index().sort_values(by='customer_unique_id', ascending=True)
df_ = df_.set_index('customer_state').rename(columns={'customer_unique_id':'Nombre_Consommateurs'})
# msk = df_['Nombre_Consommateurs'] > 1000
# df_ = df_[msk]
plt.figure(figsize=(14, 14))
df_.plot(kind='barh', stacked=True, color=['red', 'skyblue', 'green']).set_title("Nombre de consommateurs par Etat",fontsize=14)
plt.xlabel('customer_state')
plt.ylabel('Nombre_consommateurs')
# Save Figure:
plt.savefig("figures/EDA/plot_1_customers_state.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %%
df_ = customers.drop_duplicates(subset=["customer_unique_id"], keep="last")
df_ = df_.groupby('customer_state')[['customer_unique_id']].count().reset_index().sort_values(by='customer_unique_id', ascending=True)
df_ = df_.set_index('customer_state').rename(columns={'customer_unique_id':'Nombre_Consommateurs'})
msk = df_['Nombre_Consommateurs'] < 10000
df_ = df_[msk]
plt.figure(figsize=(14, 14))
ax = df_.plot(kind='barh', stacked=True, color=['red', 'skyblue', 'green'])
ax.set_title("Nombre de consommateurs par Etat", fontsize=14)
# Add annotations to the plot
for i, v in enumerate(df_['Nombre_Consommateurs']):
    ax.text(v + 500, i - 0.1, str(v), color='black')
# Save Figure:
plt.savefig("figures/EDA/plot_2_customers_state.png", transparent=True, bbox_inches='tight', dpi=200)

plt.show()

# %%
df_ = customers.drop_duplicates(subset=["customer_unique_id"], keep="last")
df_ = df_.groupby('customer_state')[['customer_unique_id']].count().reset_index().sort_values(by='customer_unique_id', ascending=True)
df_ = df_.set_index('customer_state').rename(columns={'customer_unique_id':'Nombre_Consommateurs'})
msk = df_['Nombre_Consommateurs'] > 10000
df_ = df_[msk]
plt.figure(figsize=(14, 14))
ax = df_.plot(kind='barh', stacked=True, color=['red', 'skyblue', 'green'])
ax.set_title("Nombre de consommateurs par Etat", fontsize=14)
# Add annotations to the plot
for i, v in enumerate(df_['Nombre_Consommateurs']):
    ax.text(v + 500, i - 0.1, str(v), color='black')
    
# Save Figure:
plt.savefig("figures/EDA/plot_3_customers_state.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %%
df_ = customers.drop_duplicates(subset=["customer_unique_id"], keep="last")
df_ = df_.groupby('customer_state')[['customer_unique_id']].count().reset_index().sort_values(by='customer_unique_id', ascending=True)
df_ = df_.set_index('customer_state').rename(columns={'customer_unique_id':'Nombre_Consommateurs'})
msk = df_['Nombre_Consommateurs'] < 10000
df_ = df_[msk]
plt.figure(figsize=(14, 14))
df_.plot(kind='barh', stacked=True, color=['red', 'skyblue', 'green']).set_title("Nombre de consommateurs par Etat",fontsize=14)
plt.ylabel('Nombre_consommateurs')
# Save Figure:
plt.savefig("figures/EDA/plot_4_customers_state_inf_10000.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# #### Nombre de consommateur par ville

# %%
df_ = customers.drop_duplicates(subset=["customer_unique_id"], keep="last")
df_ = df_.groupby('customer_city')[['customer_unique_id']].count().reset_index().sort_values(by='customer_unique_id', ascending=True)
df_ = df_.set_index('customer_city').rename(columns={'customer_unique_id':'Nombre_Consommateurs'})
msk = df_['Nombre_Consommateurs'] > 1000
df_ = df_[msk]
plt.figure(figsize=(14, 14))
ax = df_.plot(kind='barh', stacked=True, color=['red', 'skyblue', 'green'])
ax.set_title("Nombre de consommateurs par Etat", fontsize=14)
# Add annotations to the plot
for i, v in enumerate(df_['Nombre_Consommateurs']):
    ax.text(v + 500, i - 0.1, str(v), color='black')

plt.ylabel('Nombre_consommateurs')
# Save Figure:
plt.savefig("figures/EDA/plot_5_customers_state_sup_1000.png", transparent=True, bbox_inches='tight', dpi=200)

plt.show()

# %% [markdown]
# ### Save CSV

# %%
# transformed_customers_dataset
df = customers
path = "./data/transformed/"
filename = "transformed_customers_dataset.csv"
columns_to_save = ['customer_id', 'customer_unique_id', 'customer_state']

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Geolocation

# %% [markdown]
# geolocation : relié avec sellers (via zip_code_prefix) et cutomer (via zip_code_prefix)
#
# Le dataset geolocation est composé de 5 colonnes :
# - deux colonnes : longitude et latitude du point d'achat.
# - geolocation_zip_code_prefix : code postale.
# - geolocation_city : ville
# - geolocation_state : Etat

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.shape
# Out:
# (1000163, 5)

# %%
rapport_df(geolocation)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# geolocation_city---------------------------------- 8011
# geolocation_state--------------------------------- 27

# %%
# Information de notre data frame 
geolocation.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 146.1 MB

# %%
geolocation.isna().mean().sort_values(ascending=False) * 100
# Out:
# geolocation_zip_code_prefix    0.0
# geolocation_lat                0.0
# geolocation_lng                0.0
# geolocation_city               0.0
# geolocation_state              0.0
# dtype: float64

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# Regardons les colonnes en détail

# %% [markdown]
# **geolocation_state**

# %%
len(geolocation["geolocation_state"].unique())
# Out:
# 27

# %% [markdown]
# **geolocation_city**

# %%
len(geolocation["geolocation_city"].unique())
# Out:
# 8011

# %% [markdown]
# **geolocation_zip_code_prefix**

# %%
len(geolocation["geolocation_zip_code_prefix"].unique())
# Out:
# 19015

# %% [markdown]
# ### Analyse graphiques

# %% [markdown]
# #### Nombre de clients par Etat

# %%
fig = plt.figure(figsize=(12, 6), dpi=200)
data_plot = geolocation['geolocation_state']

sns.countplot(y=data_plot, order = geolocation['geolocation_state'].value_counts(normalize=True).index, color='g')
plt.xticks(rotation=75);
plt.title('Nombre de consommateur ', fontsize=15)
plt.xlabel('Nombre de consommateurs', fontsize=15, fontweight='bold')
# Save Figure:
plt.savefig("figures/EDA/plot_6_geolocation_state.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# Nous remarquons une cohérence avec les données de customers

# %% [markdown]
# ### Save CSV

# %%
# transformed_geolocation_dataset
df = geolocation
path = "./data/transformed/"
filename = "transformed_geolocation_dataset.csv"
columns_to_save = list(geolocation.columns)

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Order payments

# %% [markdown]
# order_payments : relié avec orders (via order_id)
#
# order_payments est composé de 5 colonnes :
# - order_id : identifiant de l'order l'achat
# - payment_sequential :
# - payment_type : type de paiment.
# - payment_installments :
# - payment_value : valeur de la commande
#
# Regardons les colonnes en détail

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.shape
# Out:
# (103886, 5)

# %% [markdown]
# Le nombre de payements est différent du nombre total

# %%
order_payments.isna().mean().sort_values(ascending=False) * 100
# Out:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64

# %%
rapport_df(order_payments)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# order_id------------------------------------------ 99440
# payment_type-------------------------------------- 5

# %%
# Information de notre data frame 
order_payments.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 17.8 MB

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# Regardons les colonnes en détail

# %% [markdown]
# **order_id**

# %%
order_payments.duplicated(subset='order_id').sum()
# Out:
# 4446

# %%
repeated_df_order_payment = order_payments['order_id'].value_counts()
repeated_df_order_payment = repeated_df_order_payment[repeated_df_order_payment > 1]
repeated_df_order_payment
# Out:
# fa65dad1b0e818e3ccc5cb0e39231352    29
# ccf804e764ed5650cd8759557269dc13    26
# 285c2e15bebd4ac83635ccc563dc71f4    22
# 895ab968e7bb0d5659d16cd74cd1650c    21
# fedcd9f7ccdc8cba3a18defedd1a5547    19
#                                     ..
# 9cd3b076bc5d4205fc15c0b23dfc78bb     2
# cda286fbc87f2e1358e2804b1d77ca0f     2
# 411b8901b201804f134429744b17b686     2
# 06f38dfd220e723c33a775d36f5d2756     2
# 3202ed2f2aeb0f12728c23faf6b61bf8     2
# Name: order_id, Length: 2961, dtype: int64

# %%
# Exemple d'un dédoublement de l'identifiant unique d'un consommateur
msk = order_payments["order_id"] == 'fedcd9f7ccdc8cba3a18defedd1a5547'
order_payments[msk]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 7548    fedcd9f7ccdc8cba3a18defedd1a5547                  15      voucher
# 9665    fedcd9f7ccdc8cba3a18defedd1a5547                   1  credit_card
# 14352   fedcd9f7ccdc8cba3a18defedd1a5547                   9      voucher
# 15264   fedcd9f7ccdc8cba3a18defedd1a5547                  11      voucher
# 15930   fedcd9f7ccdc8cba3a18defedd1a5547                   8      voucher
# 18175   fedcd9f7ccdc8cba3a18defedd1a5547                  14      voucher
# 27087   fedcd9f7ccdc8cba3a18defedd1a5547                   2      voucher
# 32396   fedcd9f7ccdc8cba3a18defedd1a5547                  13      voucher
# 35657   fedcd9f7ccdc8cba3a18defedd1a5547                  19      voucher
# 36869   fedcd9f7ccdc8cba3a18defedd1a5547                   5      voucher
# 44641   fedcd9f7ccdc8cba3a18defedd1a5547                  10      voucher
# 45197   fedcd9f7ccdc8cba3a18defedd1a5547                   4      voucher
# ...

# %% [markdown]
# #### payment_sequential
#
# payment_sequential : indique l'ordre dans lequel un paiement a été effectué pour un achat spécifique pour un type de paiment donné.

# %%
order_payments['payment_sequential'].unique()
# Out:
# array([ 1,  2,  4,  5,  3,  8,  6,  7, 10, 11, 17, 19, 27, 12,  9, 15, 13,
#        14, 16, 25, 22, 26, 29, 28, 18, 21, 24, 23, 20], dtype=int64)

# %%
order_payments["payment_sequential"].value_counts(normalize=True)
# Out:
# 1     0.956433
# 2     0.029253
# 3     0.005593
# 4     0.002676
# 5     0.001636
# 6     0.001136
# 7     0.000789
# 8     0.000520
# 9     0.000414
# 10    0.000327
# 11    0.000279
# 12    0.000202
# 13    0.000125
# 14    0.000096
# 15    0.000077
# 18    0.000058
# 19    0.000058
# 16    0.000058
# 17    0.000058
# 21    0.000039
# 20    0.000039
# 22    0.000029
# 26    0.000019
# 24    0.000019
# 23    0.000019
# 25    0.000019
# 29    0.000010
# 28    0.000010
# 27    0.000010
# Name: payment_sequential, dtype: float64

# %%
msk = order_payments["payment_sequential"] > 3
order_payments.loc[msk,'payment_type'].unique()
# Out:
# array(['voucher'], dtype=object)

# %%
msk = order_payments["payment_sequential"] > 2
order_payments.loc[msk,'payment_type'].unique()
# Out:
# array(['voucher', 'credit_card', 'debit_card'], dtype=object)

# %%
msk = order_payments["payment_sequential"] == 1
order_payments.loc[msk,'payment_type'].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %% [markdown]
# Le bon d'échange ou voucher : est le moyen le plus utiliser en plusieurs fois pour un achat donné.
#
# certaines commandes sont payées par plusieurs carte de crédit credit_card et debit_card

# %% [markdown]
# #### payment_installments
#
# payment_installments : Lorsqu'un client effectue un achat sur une plateforme de E-commerce , il peut choisir de payer le ou les articles en un seul paiement ou en plusieurs versements au fil du temps. Le nombre de versements peut varier en fonction de la plateforme et des préférences du client. Par exemple, un client peut choisir de payer un achat en deux versements, ou il peut choisir de payer en 12 versements.

# %%
order_payments['payment_installments'].unique()
# Out:
# array([ 8,  1,  2,  3,  6,  5,  4, 10,  7, 12,  9, 13, 15, 24, 11, 18, 14,
#        20, 21, 17, 22,  0, 16, 23], dtype=int64)

# %%
order_payments["payment_installments"].value_counts(normalize=True)
# Out:
# 1     0.505804
# 2     0.119487
# 3     0.100697
# 4     0.068325
# 10    0.051287
# 5     0.050430
# 8     0.041083
# 6     0.037734
# 7     0.015652
# 9     0.006199
# 12    0.001280
# 15    0.000712
# 18    0.000260
# 11    0.000221
# 24    0.000173
# 20    0.000164
# 13    0.000154
# 14    0.000144
# 17    0.000077
# 16    0.000048
# 21    0.000029
# 0     0.000019
# 22    0.000010
# 23    0.000010
# Name: payment_installments, dtype: float64

# %%
msk = order_payments["payment_installments"] == 0
order_payments[msk]
# Out:
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 79014  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69
# 79014                     0         129.94

# %%
order_payments['payment_installments'].unique()
# Out:
# array([ 8,  1,  2,  3,  6,  5,  4, 10,  7, 12,  9, 13, 15, 24, 11, 18, 14,
#        20, 21, 17, 22,  0, 16, 23], dtype=int64)

# %% [markdown]
# **payment_type**

# %%
order_payments["payment_type"].value_counts(normalize=True)
# Out:
# credit_card    0.739224
# boleto         0.190440
# voucher        0.055590
# debit_card     0.014718
# not_defined    0.000029
# Name: payment_type, dtype: float64

# %% [markdown]
# ### Analyse graphiques

# %%
# data
data = order_payments["payment_type"].value_counts()
labels = list(order_payments["payment_type"].unique())
# Seaborn color palette to use
colors = sns.color_palette('colorblind')[0:5]
# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the pie chart on the axis
ax.pie(data, labels=labels, colors=colors, autopct='%.0f%%', pctdistance=1.3)

# Add a legend to the chart
ax.legend(title="Payment Types", loc="center left", bbox_to_anchor=(1, 0.2, 0.5, 1))
# Save Figure:
plt.savefig("figures/EDA/plot_7_order_payments_payment_type.png", transparent=True, bbox_inches='tight', dpi=200)

# Show the plot
plt.show()

# %% [markdown]
# ### Save CSV

# %%
# transformed_order_payments_dataset
df = order_payments
path = "./data/transformed/"
filename = "transformed_order_payments_dataset.csv"
columns_to_save = list(order_payments.columns)

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Orders

# %% [markdown]
# orders : relié avec order_payments (via order_id), order_reviews (via order_id), order_customer (via cutomer_id) et order_items(via order_id)
#
# orders est composé de 8 colonnes :
# - order_id : identifiant de l'order l'achat
# - customer_id :
# - order_status : statut de la livraison.
# - order_purchase_timestamp : date et heure à laquelle la commande est passée
# - order_approved_at : date et validation de la commande par le vendeur
# - order_delivered_carrier_date : date et heure de l'envoi de la commande par le transporteur.
# - order_delivered_customer_date : date et heure de la livraison chez le consommateur
# - order_estimated_delivery_date : date estimée de la livraison.

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.shape
# Out:
# (99441, 8)

# %%
rapport_df(orders)
# Out:
# Le Taux de remplissage total est égal à : 99.38305125652397 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# order_id------------------------------------------ 99441
# customer_id--------------------------------------- 99441
# order_status-------------------------------------- 8
# order_purchase_timestamp-------------------------- 98875
# order_approved_at--------------------------------- 90734
# order_delivered_carrier_date---------------------- 81019
# order_delivered_customer_date--------------------- 95665
# order_estimated_delivery_date--------------------- 459

# %%
orders.isna().mean().sort_values(ascending=False) * 100
# Out:
# order_delivered_customer_date    2.981668
# order_delivered_carrier_date     1.793023
# order_approved_at                0.160899
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
# Information de notre data frame 
orders.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 59.0 MB

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# Regardons les colonnes en détail

# %% [markdown]
# **order_id**

# %%
orders.duplicated(subset='order_id').sum()
# Out:
# 0

# %%
# Exemple d'un dédoublement de l'identifiant unique d'un consommateur
msk = orders["order_id"] == '7c48bb55e8e4f7e56d412e9653db37bc'
orders[msk]
# Out:
#                                order_id                       customer_id  \
# 25883  7c48bb55e8e4f7e56d412e9653db37bc  34ef6181341eb36c47fd601c46878f00
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 25883    delivered      2018-07-16 18:40:53  2018-07-16 18:50:22
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 25883          2018-01-26 13:35:00           2018-07-23 20:04:45
#
#       order_estimated_delivery_date
# 25883           2018-08-07 00:00:00

# %% [markdown]
# **customer_id**

# %%
orders.duplicated(subset='customer_id').sum()
# Out:
# 0

# %%
orders.duplicated(subset=['order_id','customer_id']).sum()
# Out:
# 0

# %% [markdown]
# **order_status**

# %%
orders.duplicated(subset='order_status').sum()
# Out:
# 99433

# %% [markdown]
# **order_delivered_customer_date**

# %%
msk = orders["order_delivered_customer_date"].isna()
orders.loc[msk, "order_status"].unique()
# Out:
# array(['invoiced', 'shipped', 'processing', 'unavailable', 'canceled',
#        'delivered', 'created', 'approved'], dtype=object)

# %%
msk = (orders["order_delivered_customer_date"].isna()) & (orders["order_status"] == "delivered")
orders[msk]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07  2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43  2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11  2018-07-01 17:15:12
# ...

# %%
# Les Colonnes Dates : re_typage 
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
df = orders.copy()

# %%
# pAnomalies
df.loc[(df['order_approved_at'] > df['order_delivered_carrier_date'])]
# Out:
#                                order_id                       customer_id  \
# 15     dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 64     688052146432ef8253587b930b01a06d  81e08b08e5ed4472008030d70327c71f
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 210    412fccb2b44a99b36714bca3fef8ad7b  c6865c523687cb3f235aa599afef1710
# 415    56a4ac10a4a8f2ba7693523bb439eede  78438ba6ace7d2cb023dbbc81b083562
# ...                                 ...                               ...
# 99091  240ead1a7284667e0ec71d01f80e4d5e  fcdd7556401aaa1c980f8b67a69f95dc
# 99230  78008d03bd8ef7fcf1568728b316553c  043e3254e68daf7256bda1c9c03c2286
# 99266  76a948cd55bf22799753720d4545dd2d  3f20a07b28aa252d0502fe7f7eb030a9
# 99377  a6bd1f93b7ff72cc348ca07f38ec4bee  6d63fa86bd2f62908ad328325799152f
# 99406  7fd85cb0143de098a4c5ab5a57bfbd91  d32034dfc685b1ae15dd4c78eace868e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Anomalies
df.loc[(df['order_delivered_carrier_date'] > df['order_delivered_customer_date'])]
# Out:
#                                order_id                       customer_id  \
# 6437   a1abeb653a4d4cd1e142ccb8c82cd069  5f50465da00b7fed5dd1239f4ecf6e2c
# 9553   383aa8b2724fe452d9ccd9934a8c628b  b1cb2f9d7a19480f3749e248db14d58f
# 13487  cb1134f9010d242e9515ad1c78ec0c39  2fd33ac77677bd214b1882868317eeed
# 14474  dceb62e8fa94b46006c9554fed743df0  2721900eb4e0f1cc2c836dd7bc1b1e11
# 19268  5f9d46795c3126674e52becb3a1a517f  79287bcaafdde5c793b996fc40bb7d9f
# 21338  8c78d01de3a9009e23d6877a7cc9be20  6cd7106899e59a1fbd0622d5f1efedf4
# 22520  b27af682321527a6349f1761eb3f360c  9859dd92e872dbaa60ca3cd5f0d7ad07
# 25393  1cc3ae63caffff2d6c3ee3e78e074acf  01c843a2c0600def0b7693dba47af460
# 25646  e37f11cae9985ca58f0b56f268720537  3947a361301f2ff0f3223159a0f2701c
# 27470  fa3e37584f4fdb1ded0e0de700dfcb4e  63be4feff10a0b1d85f2cfbf10df9754
# 34939  c1e2bf2b7dd3309f2f5356c6b63968fa  e37d47e7eec62f08dc5deecc7d5532d6
# 41636  b866af202be0692766081310cd4085e1  d1800078046ed2e5ae1b0792b695c56e
# ...

# %%
# Anomalies
df.loc[(df['order_delivered_customer_date'] > df['order_estimated_delivery_date'])]
# Out:
#                                order_id                       customer_id  \
# 20     203096f03d82e0dffbc41ebc2e2bcfb7  d2b091571da224a1b36412c18bc3bbfe
# 25     fbf9ac61453ac646ce8ad9783d7d0af6  3a874b4d4c4b6543206ff5d89287f0c3
# 35     8563039e855156e48fccee4d611a3196  5f16605299d698660e0606f7eae2d2f9
# 41     6ea2f835b4556291ffdc53fa0b3b95e8  c7340080e394356141681bd4c9b8fe31
# 57     66e4624ae69e7dc89bd50222b59f581f  684fa6da5134b9e4dab731e00011712d
# ...                                 ...                               ...
# 99396  b3112ca67f3afd4e20cf2ee91fc4f804  6f83c71b6c044fb156d697d4130fe9b5
# 99397  0fa1fab1d7c1211c824596ed5e111e3c  7f3bd6c94d2daf7b6462d1a894a775b4
# 99423  38e9133ce29f6bbe35aed9c3863dce01  ad312389a098ceff46ce92c4595c06d0
# 99425  d692ef54145c9cb3322ec2e5508aa3f4  82ddfcf9438b0cd1117b55ac33184df8
# 99432  cfa78b997e329a5295b4ee6972c02979  a2f7428f0cafbc8e59f20e1444b67315
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Anomalies
df.loc[(df['order_purchase_timestamp'] > df['order_delivered_customer_date'])]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
# Anomalies
df.loc[(df['order_approved_at'] > df['order_delivered_customer_date'])]
# Out:
#                                order_id                       customer_id  \
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 483    4df92d82d79c3b52c7138679fa9b07fc  ba0660bf3fffe505ee892e153a2fbd49
# 1986   6e57e23ecac1ae881286657694444267  2dda54e25d0984e12705c84d4030e6e0
# 3659   f222c56f035b47dfa1e069a88235d730  b74ca180d63f9ae0443e4e13a2f5bdaf
# 11738  cf72398d0690f841271b695bbfda82d2  2b7fff075bda701552485ef3f0810257
# 13470  6df6c9c9af6ef75b4f06f8a7b9f47e9c  2e1a3155fdbee565b7ad55cb75ce8f78
# 14562  1fab4ac9d85079b3da72a11475ae1685  f831c1fa80308975ec2b58e4877328e0
# 16345  fa962e76e50f3469ae2abfa54e6d5be0  aa80dff2d54c89d3bc5040a9dbe5108c
# 18097  0467205a89711e4ec8e70ef2277e3287  90b8af517fbab96fb08d0115dffdc570
# 20557  ecd1661658d34312cf9ac2bf34ba3b6b  bcec3938d91ba9a3bf2c4261a44cb9f3
# 24212  8b83251dbc9bd02530320cceb82cc03e  7aa78ec38a25e08bf82617d92a583d0f
# 24823  6d1832bd42dccbd91d1ce32da7f54492  1d12f3eea210892c245c9be2bd17a93c
# ...

# %%
# On garde les commandes qui ont été livrées : 
orders = orders[orders['order_status'] == 'delivered']

# %%
orders = orders.drop(columns=['order_approved_at', 'order_delivered_carrier_date'])

# %%
orders.isna().mean().sort_values(ascending=False) * 100
# Out:
# order_delivered_customer_date    0.008292
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_estimated_delivery_date    0.000000
# dtype: float64

# %% [markdown]
# **Colonnes : Dates et Heures**

# %%
# Commençon par corriger le types des données de nos colonnes Dates et Heures : 
dates_heures_columns = ['order_purchase_timestamp',
       
       'order_delivered_customer_date', 'order_estimated_delivery_date']

for col in dates_heures_columns:
    orders[col] = pd.to_datetime(orders[col])

# %%
# Vérification 
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Missing values

# %% [markdown]
# #### order_delivered_customer_date

# %%
msk = orders['order_delivered_customer_date'].isna()
orders[msk]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp order_delivered_customer_date  \
# 3002     delivered      2017-11-28 17:44:07                           NaT
# 20618    delivered      2018-06-20 06:58:43                           NaT
# 43834    delivered      2018-07-01 17:05:11                           NaT
# ...

# %%
# Récupération de la date sans l'heure
msk_order_purchase  = orders.loc[msk, 'order_purchase_timestamp'].apply(lambda x: x.timestamp())
msk_delivered_carrie  = orders.loc[msk, 'order_estimated_delivery_date'].apply(lambda x: x.timestamp())

# %%
# Calcul du temps moyen entre les deux dates : 
mean_date_msk = (msk_order_purchase + msk_delivered_carrie ) / 2
datetime_objects = np.array(mean_date_msk, dtype='datetime64[s]').astype(dt.date)

# Fill missing values : 
orders.loc[msk, 'order_delivered_customer_date'] = datetime_objects

# %%
orders.isna().mean().sort_values(ascending=False) * 100
# Out:
# order_id                         0.0
# customer_id                      0.0
# order_status                     0.0
# order_purchase_timestamp         0.0
# order_delivered_customer_date    0.0
# order_estimated_delivery_date    0.0
# dtype: float64

# %%
# Vérification 
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %% [markdown]
# **Temps pour recevoir la commande**

# %%
# Délai de livraison d'une commande
orders['time_to_delivery'] = orders['order_delivered_customer_date'] - orders['order_purchase_timestamp']

# %%
# Délai de livraison en jours
orders['days_to_delivery'] = orders['time_to_delivery'].dt.days

# %% [markdown]
# **Temps estimé pour recevoir la commande**

# %%
# Délai de livraison estimùé d'une commande
orders['estimated_time_to_delivery'] = orders['order_estimated_delivery_date'] - orders['order_purchase_timestamp']

# %%
# Délai de livraison estimé  en jours
orders['estimated_days_to_delivery'] = orders['estimated_time_to_delivery'].dt.days

# %% [markdown]
# **Extraction Jour de Semain et Heures de chaque commande**

# %%
# Jour de la semaine pour passer une commande
# orders["day_of_week_purchase"] = orders["order_purchase_timestamp"].apply(lambda x: x.strftime("%a"))
# orders["time_purchase"] = orders["order_purchase_timestamp"].apply(lambda x: x.strftime("%H:%M"))

# %%
# Jour de la semaine pour passer une commande
orders["day_of_week_purchase"] = orders["order_purchase_timestamp"].dt.day_name()
orders["time_purchase"] = orders["order_purchase_timestamp"].dt.hour

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-10-02 10:56:33           2017-10-10 21:25:13
# 1    delivered      2018-07-24 20:41:37           2018-08-07 15:27:45
# 2    delivered      2018-08-08 08:38:49           2018-08-17 18:06:29
# 3    delivered      2017-11-18 19:28:06           2017-12-02 00:28:42
# 4    delivered      2018-02-13 21:18:39           2018-02-16 18:17:02
#
#   order_estimated_delivery_date time_to_delivery  days_to_delivery  \
# ...

# %% [markdown]
# ### Analyse graphiques

# %%
# grouper par jour et heure et compter le nombre de commandes
grouped = orders.groupby(['day_of_week_purchase', 'time_purchase']).count().reset_index()

# pivot 
pivoted = grouped.pivot('time_purchase', 'day_of_week_purchase', 'order_id')

# heatmap
sns.heatmap(pivoted, cmap='Blues')
plt.title('Number of Orders per Day and Time')
# Save Figure:
plt.savefig("figures/EDA/plot_8_orders_number_orders_day_time.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# **Distribution nombre de Jours Validation/Envoi/Reception/Delai de Livraison estimé**

# %%
# Distributions 
columns = [
       'days_to_delivery',
       'estimated_days_to_delivery']
plot_distribution(orders, columns)

# %% [markdown]
# **Distributions Jours Validation/Envoi/Livraison/Livraison estimée : Commande Livrées en moins de 10 jours**

# %% [markdown]
# ### Save CSV

# %%
# transformed_orders_dataset
df = orders
path = "./data/transformed/"
filename = "transformed_orders_dataset.csv"
columns_to_save = list(orders.columns)

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Order_items

# %% [markdown]
# order_items : relié avec products (via product_id), sellers (via seller_id), orders (via order_id) et order_items(via order_id)
#
# order_items est composé de 7 colonnes :
# - order_id : identifiant de l'order l'achat
# - order_item_id :
# - product_id : statut de la livraison.
# - seller_id : date et heure à laquelle la commande est passée
# - shipping_limit_date : date et validation de la commande par le vendeur
# - price : prix de la commande
# - freight_value : frais de port

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
rapport_df(order_items)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# order_id------------------------------------------ 98666
# product_id---------------------------------------- 32951
# seller_id----------------------------------------- 3095
# shipping_limit_date------------------------------- 93318

# %%
order_items.isna().mean().sort_values(ascending=False) * 100
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
# Information de notre data frame 
order_items.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 39.4 MB

# %%
# Vérification des anomalies
msk = order_items['price'] == 0
order_items[msk]
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
# Vérification des anomalies : sans frais de port (c'est normal)
msk = order_items['freight_value'] == 0
order_items[msk]
# Out:
#                                 order_id  order_item_id  \
# 114     00404fa7a687c8c44ca69d42695aae73              1
# 258     00a870c6c06346e85335524935c600c0              1
# 483     011c899816ea29773525bd3322dbb6aa              1
# 508     012b3f6ab7776a8ab3443a4ad7bef2e6              1
# 509     012b3f6ab7776a8ab3443a4ad7bef2e6              2
# ...                                  ...            ...
# 111094  fc698f330ec7fb74859071cc6cb29772              1
# 111497  fd4907109f6bac23f07064af84bec02d              1
# 111649  fd95e4b85ebbb81853d4a6be3d61432b              1
# 112182  fee19a0dc7358b6962a611cecf6a37b4              1
# 112607  ffe73fc1d73e03fdb50e63903ddfe882              1
#
#                               product_id                         seller_id  \
# 114     53b36df67ebb7c41585e8d54d6772e08  7d13fca15225358621be4086e1eb0964
# 258     aca2eb7d00ea1a7b8ebd4e68314663af  955fee9216a65b617aa5c0531780ce60
# ...

# %%
order_items['order_id'].value_counts()
# Out:
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 5a0911d70c1f85d3bed0df1bf693a6dd     1
# 5a082b558a3798d3e36d93bfa8ca1eae     1
# 5a07264682e0b8fbb3f166edbbffc6e8     1
# 5a071192a28951b76774e5a760c8c9b7     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: order_id, Length: 98666, dtype: int64

# %%
# Numbre d'article par commande
count_articl_by_order = order_items['order_id'].value_counts()
count_articl_by_order = count_articl_by_order[count_articl_by_order > 1]
count_articl_by_order.sort_values(ascending=False)
# Out:
# 8272b63d03f5f79c56e9e4120aec44ef    21
# ab14fdcfbe524636d65ee38360e22ce8    20
# 1b15974a0141d54e36626dca3fdc731a    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# e475e7ce217d2a677451521dce3d35d2     2
# 6e6242aabab7596add1baa594d4e7208     2
# e478568cc3d592abd0ea9dde224012af     2
# cedde3e913410b115a589c84c79b263a     2
# 8f95a252fcb4d9163d1f674ac0c746bb     2
# Name: order_id, Length: 9803, dtype: int64

# %% [markdown]
# 9803 Commandes comportent au moins 2 articles

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# Regardons les colonnes en détail

# %% [markdown]
# **order_id**

# %%
order_items.duplicated(subset='order_id').sum()
# Out:
# 13984

# %% [markdown]
# **order_item_id**

# %%
order_items.duplicated(subset='order_item_id').sum()
# Out:
# 112629

# %% [markdown]
# **seller_id**

# %%
order_items.duplicated(subset='seller_id').sum()
# Out:
# 109555

# %% [markdown]
# **shipping_limit_date**

# %%
order_items.duplicated(subset='shipping_limit_date').sum()
# Out:
# 19332

# %% [markdown]
# **Colonnes : Dates et Heures**

# %%
# Commençon par corriger le types des données de nos colonnes Dates et Heures : 
dates_heures_columns = ['shipping_limit_date']

for col in dates_heures_columns:
    order_items[col] = pd.to_datetime(order_items[col])

# %%
# Vérification 
order_items.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# ### Analyse graphiques

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# Groupby : rder_id
order_items_grouped = order_items.groupby('order_id').agg({
    'order_item_id': 'mean',
    "price": 'mean',
    "freight_value": 'mean'
           
})
order_items_grouped = order_items_grouped.reset_index()
order_items_grouped.columns = ['order_id', 'max_items','mean_price', 'mean_freight']

order_items_grouped.head()
# Out:
#                            order_id  max_items  mean_price  mean_freight
# 0  00010242fe8c5a6d1ba2dd792cb16214        1.0       58.90         13.29
# 1  00018f77f2f0320c557190d7a144bdd3        1.0      239.90         19.93
# 2  000229ec398224ef6ca0657da4fc703e        1.0      199.00         17.87
# 3  00024acbcdf0a6daa1e931b038114c75        1.0       12.99         12.79
# 4  00042b26cf59d7ce69dfabb4e55b4fd9        1.0      199.90         18.14

# %%
# Distributions 
columns = ['max_items',
           'mean_price', 
           'mean_freight']
plot_distribution(order_items_grouped, columns)

# %% [markdown]
# ### Save CSV

# %%
order_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
# transformed_order_items_dataset
df = order_items
path = "./data/transformed/"
filename = "transformed_order_items_dataset.csv"
columns_to_save = ['order_id', 'product_id', 'order_item_id', 'price', 'freight_value', 'seller_id' ]

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Order_reviews

# %% [markdown]
# order_reviews : relié avec orders (via order_id)
#
# order_items est composé de 7 colonnes :
# - review_id : identifiant du commentaire
# - order_id : identifiant de la commande
# - review_score : score commentaire.
# - review_comment_title : titre du commentaire
# - review_comment_message : contenu du commentaire
# - review_creation_date : date création du commentaire
# - review_answer_timestamp : réponse au commentaire date et heure

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.shape
# Out:
# (99224, 7)

# %%
order_reviews.isna().mean().sort_values(ascending=False) * 100
# Out:
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
rapport_df(order_reviews)
# Out:
# Le Taux de remplissage total est égal à : 78.99370543992814 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# review_id----------------------------------------- 98410
# order_id------------------------------------------ 98673
# review_comment_title------------------------------ 4528
# review_comment_message---------------------------- 36160
# review_creation_date------------------------------ 636
# review_answer_timestamp--------------------------- 98248

# %%
# Information de notre data frame 
order_reviews.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 42.7 MB

# %%
duplicates = order_reviews.duplicated(subset=['review_id', 'order_id'])
print(duplicates.sum())
# Out:
# 0

# %%
order_reviews = order_reviews.drop_duplicates(subset=['order_id'])

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# **review_id**

# %%
order_reviews.duplicated(subset='review_id').sum()
# Out:
# 517

# %% [markdown]
# **order_id**

# %%
order_reviews.duplicated(subset='order_id').sum()
# Out:
# 0

# %% [markdown]
# **review_score**

# %%
len(order_reviews['review_score'].unique())
# Out:
# 5

# %% [markdown]
# **Colonnes : Dates et Heures**

# %%
# Commençon par corriger le types des données de nos colonnes Dates et Heures : 
dates_heures_columns = ['review_creation_date',
       'review_answer_timestamp']

for col in dates_heures_columns:
    order_reviews[col] = pd.to_datetime(order_reviews[col])

# %%
# Vérification 
order_reviews.dtypes
# Out:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_comment_title               object
# review_comment_message             object
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
# Groupby : rder_id
order_reviews = order_reviews.groupby('order_id').agg({
    'review_score': 'mean',
       
})
order_reviews = order_reviews.reset_index()
order_reviews.head()
# Out:
#                            order_id  review_score
# 0  00010242fe8c5a6d1ba2dd792cb16214           5.0
# 1  00018f77f2f0320c557190d7a144bdd3           4.0
# 2  000229ec398224ef6ca0657da4fc703e           5.0
# 3  00024acbcdf0a6daa1e931b038114c75           4.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9           5.0

# %%
order_reviews['review_score'].sort_values()
# Out:
# 99223    1
# 67160    1
# 67149    1
# 67148    1
# 67147    1
#         ..
# 57669    5
# 22712    5
# 22708    5
# 57657    5
# 49611    5
# Name: review_score, Length: 99224, dtype: int64

# %% [markdown]
# ### Analyse graphiques

# %%
# data

data = order_reviews["review_score"].value_counts()
labels = list(order_reviews["review_score"].unique())
# Seaborn color palette to use
colors = sns.color_palette('colorblind')[0:5]
# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the pie chart on the axis
ax.pie(data, labels=labels, colors=colors, autopct='%.0f%%', pctdistance=1.3)

# Add a legend to the chart
ax.legend(title="review_score", loc="center left", bbox_to_anchor=(1, 0.2, 0.5, 1))
# Save Figure:
plt.savefig("figures/EDA/plot_9_review_score_reviews.png", transparent=True, bbox_inches='tight', dpi=200)

# Show the plot
plt.show()

# %% [markdown]
# ### Save CSV

# %%
# transformed_order_reviews_dataset
df = order_reviews
path = "./data/transformed/"
filename = "transformed_order_reviews_dataset.csv"
columns_to_save = ['order_id', 'review_score']

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Products

# %% [markdown]
# products : relié avec orders (via order_id)
#
# order_items est composé de 7 colonnes :
# - review_id : identifiant du commentaire
# - order_id : identifiant de la commande
# - review_score : score commentaire.
# - review_comment_title : titre du commentaire
# - review_comment_message : contenu du commentaire
# - review_creation_date : date création du commentaire
# - review_answer_timestamp : réponse au commentaire date et heure

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.shape
# Out:
# (32951, 9)

# %%
products.isna().mean().sort_values(ascending=False) * 100
# Out:
# product_category_name         1.851234
# product_name_lenght           1.851234
# product_description_lenght    1.851234
# product_photos_qty            1.851234
# product_weight_g              0.006070
# product_length_cm             0.006070
# product_height_cm             0.006070
# product_width_cm              0.006070
# product_id                    0.000000
# dtype: float64

# %%
rapport_df(products)
# Out:
# Le Taux de remplissage total est égal à : 99.1745318806713 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# product_id---------------------------------------- 32951
# product_category_name----------------------------- 74

# %%
# Information de notre data frame 
products.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 6.8 MB

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# **product_id**

# %%
products.duplicated(subset='product_id').sum()
# Out:
# 0

# %% [markdown]
# ### Save CSV

# %%
# transformed_products_dataset
df = products
path = "./data/transformed/"
filename = "transformed_products_dataset.csv"
columns_to_save = ['product_id', 'product_category_name']

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ##  Sellers

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.shape
# Out:
# (3095, 4)

# %%
sellers.isna().mean().sort_values(ascending=False) * 100
# Out:
# seller_id                 0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64

# %%
rapport_df(sellers)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# seller_id----------------------------------------- 3095
# seller_city--------------------------------------- 611
# seller_state-------------------------------------- 23

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# **seller_id**

# %%
sellers.duplicated(subset='seller_id').sum()
# Out:
# 0

# %% [markdown]
# ### Save CSV

# %%
# transformed_sellers_dataset
df = sellers
path = "./data/transformed/"
filename = "transformed_sellers_dataset.csv"
columns_to_save = ['seller_id', 'seller_state']

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# ## Category Name Translation

# %%
# Importation du dataset
path = "./data/source/"
filename = "product_category_name_translation.csv"
product_category_name = pd.read_csv(path+filename)

# %%
product_category_name.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_category_name.shape
# Out:
# (71, 2)

# %%
rapport_df(product_category_name)
# Out:
# Le Taux de remplissage total est égal à : 100.0 %
# Le Nombre de features vides est égal à : 0 Features
# Les Features vides sont : []
#
# *****Nombre de catégorie features catégorielles******
#
# product_category_name----------------------------- 71
# product_category_name_english--------------------- 71

# %%
product_category_name.isna().mean().sort_values(ascending=False)
# Out:
# product_category_name            0.0
# product_category_name_english    0.0
# dtype: float64

# %%
# Information de notre data frame 
product_category_name.info(verbose=True,show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 10.3 KB

# %% [markdown]
# ### Analyse des colonnes

# %% [markdown]
# **product_category_name**

# %%
product_category_name.duplicated(subset='product_category_name').sum()
# Out:
# 0

# %%
product_category_name["product_category_name"].unique()
# Out:
# array(['beleza_saude', 'informatica_acessorios', 'automotivo',
#        'cama_mesa_banho', 'moveis_decoracao', 'esporte_lazer',
#        'perfumaria', 'utilidades_domesticas', 'telefonia',
#        'relogios_presentes', 'alimentos_bebidas', 'bebes', 'papelaria',
#        'tablets_impressao_imagem', 'brinquedos', 'telefonia_fixa',
#        'ferramentas_jardim', 'fashion_bolsas_e_acessorios',
#        'eletroportateis', 'consoles_games', 'audio', 'fashion_calcados',
#        'cool_stuff', 'malas_acessorios', 'climatizacao',
#        'construcao_ferramentas_construcao',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
#        'construcao_ferramentas_jardim', 'fashion_roupa_masculina',
#        'pet_shop', 'moveis_escritorio', 'market_place', 'eletronicos',
#        'eletrodomesticos', 'artigos_de_festas', 'casa_conforto',
#        'construcao_ferramentas_ferramentas', 'agro_industria_e_comercio',
#        'moveis_colchao_e_estofado', 'livros_tecnicos', 'casa_construcao',
# ...

# %% [markdown]
# **product_category_name_english**

# %%
product_category_name.duplicated(subset='product_category_name_english').sum()
# Out:
# 0

# %%
product_category_name["product_category_name_english"].unique()
# Out:
# array(['health_beauty', 'computers_accessories', 'auto', 'bed_bath_table',
#        'furniture_decor', 'sports_leisure', 'perfumery', 'housewares',
#        'telephony', 'watches_gifts', 'food_drink', 'baby', 'stationery',
#        'tablets_printing_image', 'toys', 'fixed_telephony',
#        'garden_tools', 'fashion_bags_accessories', 'small_appliances',
#        'consoles_games', 'audio', 'fashion_shoes', 'cool_stuff',
#        'luggage_accessories', 'air_conditioning',
#        'construction_tools_construction',
#        'kitchen_dining_laundry_garden_furniture',
#        'costruction_tools_garden', 'fashion_male_clothing', 'pet_shop',
#        'office_furniture', 'market_place', 'electronics',
#        'home_appliances', 'party_supplies', 'home_confort',
#        'costruction_tools_tools', 'agro_industry_and_commerce',
#        'furniture_mattress_and_upholstery', 'books_technical',
#        'home_construction', 'musical_instruments',
# ...

# %% [markdown]
# ### Save CSV

# %%
# transformed_product_category_name_dataset
df = product_category_name
path = "./data/transformed/"
filename = "transformed_product_category_name_dataset.csv"
columns_to_save = list(product_category_name.columns)

# Save
save_transformed_df(df, path, filename, columns_to_save)

# %% [markdown]
# # Merge

# %% [markdown]
# ## Importation des fichier

# %%
liste_data_transformed = os.listdir("data/transformed")

# %%
liste_data_transformed
# Out:
# ['transformed_customers_dataset.csv',
#  'transformed_geolocation_dataset.csv',
#  'transformed_orders_dataset.csv',
#  'transformed_order_items_dataset.csv',
#  'transformed_order_payments_dataset.csv',
#  'transformed_order_reviews_dataset.csv',
#  'transformed_products_dataset.csv',
#  'transformed_product_category_name_dataset.csv',
#  'transformed_sellers_dataset.csv']

# %%
# Récupération des noms de datasets
# initializing substrings
sub1 = ""
sub2 = "_dataset.csv"
idx1 = 0
idx2 = 0
liste_name = []
for name in liste_data_transformed:
    # getting index of substrings
    name = str(name)
    idx1 = name.index(sub1)
    idx2 = name.index(sub2)
    res = ''
    for idx in range(idx1 + len(sub1) , idx2):
        res = res + name[idx]
    #printing result
    name_= str(res)
    liste_name.append(name_)

# %%
liste_name
# Out:
# ['transformed_customers',
#  'transformed_geolocation',
#  'transformed_orders',
#  'transformed_order_items',
#  'transformed_order_payments',
#  'transformed_order_reviews',
#  'transformed_products',
#  'transformed_product_category_name',
#  'transformed_sellers']

# %%
path = "./data/transformed/"
for i, name in enumerate(liste_name):
    exec(f"{name} = pd.read_csv(path + liste_data_transformed[i])")

# %%
datasets = [transformed_customers, 
            transformed_geolocation,
            transformed_orders, 
            transformed_order_items,
            transformed_order_payments,
            transformed_order_reviews,
            transformed_products,
            transformed_product_category_name, 
            transformed_sellers]

# CE CODE EST COPIE
data_summary = pd.DataFrame({},)
data_summary['datasets']= liste_name
data_summary['columns'] = [', '.join([col for col, null in data.isnull().sum().items() ]) for data in datasets]
data_summary['total_rows']= [data.shape[0] for data in datasets]
data_summary['total_cols']= [data.shape[1] for data in datasets]
data_summary['total_duplicate']= [len(data[data.duplicated()]) for data in datasets]
data_summary['total_null']= [data.isnull().sum().sum() for data in datasets]
data_summary['null_cols'] = [', '.join([col for col, null in data.isnull().sum().items() if null > 0]) for data in datasets]
data_summary.style.background_gradient(cmap='YlGnBu')
# Out:
# <style type="text/css">
# #T_40a81_row0_col2, #T_40a81_row0_col3, #T_40a81_row2_col2, #T_40a81_row5_col2 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_40a81_row0_col4, #T_40a81_row0_col5, #T_40a81_row1_col5, #T_40a81_row2_col4, #T_40a81_row2_col5, #T_40a81_row3_col4, #T_40a81_row3_col5, #T_40a81_row4_col4, #T_40a81_row4_col5, #T_40a81_row5_col3, #T_40a81_row5_col4, #T_40a81_row5_col5, #T_40a81_row6_col3, #T_40a81_row6_col4, #T_40a81_row7_col2, #T_40a81_row7_col3, #T_40a81_row7_col4, #T_40a81_row7_col5, #T_40a81_row8_col2, #T_40a81_row8_col3, #T_40a81_row8_col4, #T_40a81_row8_col5 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_40a81_row1_col2, #T_40a81_row1_col4, #T_40a81_row2_col3, #T_40a81_row6_col5 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_40a81_row1_col3, #T_40a81_row4_col3 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_40a81_row3_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_40a81_row3_col3 {
# ...

# %%
transformed_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP

# %%
transformed_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-10-02 10:56:33           2017-10-10 21:25:13
# 1    delivered      2018-07-24 20:41:37           2018-08-07 15:27:45
# 2    delivered      2018-08-08 08:38:49           2018-08-17 18:06:29
# 3    delivered      2017-11-18 19:28:06           2017-12-02 00:28:42
# 4    delivered      2018-02-13 21:18:39           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  time_to_delivery  days_to_delivery  \
# ...

# %%
transformed_order_items.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#    order_item_id   price  freight_value                         seller_id
# 0              1   58.90          13.29  48436dade18ac8b2bce089ec2a041202
# 1              1  239.90          19.93  dd7ddc04e1b6c2c614352b383efe2d36
# 2              1  199.00          17.87  5b51032eddd242adc84c38acab88f23d
# 3              1   12.99          12.79  9d7a1d34a5052409006425275ba1c2b4
# 4              1  199.90          18.14  df560393f3a51e74553ab94004ba5c87

# %%
transformed_order_reviews.head()
# Out:
#                            order_id  review_score
# 0  00010242fe8c5a6d1ba2dd792cb16214           5.0
# 1  00018f77f2f0320c557190d7a144bdd3           4.0
# 2  000229ec398224ef6ca0657da4fc703e           5.0
# 3  00024acbcdf0a6daa1e931b038114c75           4.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9           5.0

# %% [markdown]
# ## transformed_orders + transformed_order_items

# %%
cols= [
    'order_id',
    'customer_id',
    'order_status',
    'time_to_delivery',
    'days_to_delivery',
    'day_of_week_purchase',
    'time_purchase',
    'estimated_days_to_delivery',
    'order_purchase_timestamp',
    'order_item_id',
    'product_id',
    'price',
    'freight_value'
]

orders_complet = pd.merge(
    left= transformed_orders,
    right= transformed_order_items,
    on= 'order_id',
    how= 'inner'
)[cols]

orders_complet.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status  time_to_delivery  days_to_delivery day_of_week_purchase  \
# 0    delivered   8 days 10:28:40                 8               Monday
# 1    delivered  13 days 18:46:08                13              Tuesday
# 2    delivered   9 days 09:27:40                 9            Wednesday
# 3    delivered  13 days 05:00:36                13             Saturday
# 4    delivered   2 days 20:58:23                 2              Tuesday
#
#    time_purchase  estimated_days_to_delivery order_purchase_timestamp  \
# ...

# %% [markdown]
# ## orders_complet + transformed_customers

# %%
orders_complet.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'time_to_delivery',
#        'days_to_delivery', 'day_of_week_purchase', 'time_purchase',
#        'estimated_days_to_delivery', 'order_purchase_timestamp',
#        'order_item_id', 'product_id', 'price', 'freight_value'],
#       dtype='object')

# %%
cols =['customer_unique_id','order_id', 'customer_id', 'order_status', 'time_to_delivery',
       'days_to_delivery', 'day_of_week_purchase', 'time_purchase',
       'estimated_days_to_delivery', 'order_purchase_timestamp',
       'order_item_id', 'product_id', 'price', 'freight_value']

customers_orders = pd.merge(
    left= orders_complet,
    right= transformed_customers,
    on= 'customer_id',
    how= 'inner'
)[cols]

customers_orders.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
# 2  3a653a41f6f9fc3d2a113cf8398680e8  47770eb9100c2d0c44946d9cf07ec65d
# 3  7c142cf63193a1473d2e66489a9ae977  949d5b44dbf5de918fe9c16f97b45f8a
# 4  72632f0f9dd73dfee390c9b22eb56dd6  ad21c59c0840e6cb83a9ceb5573f8159
#
#                         customer_id order_status  time_to_delivery  \
# 0  9ef432eb6251297304e76186b10a928d    delivered   8 days 10:28:40
# 1  b0830fb4747a6c6d20dea0b8c802d7ef    delivered  13 days 18:46:08
# 2  41ce2a54c0b03bf3443c3d931a367089    delivered   9 days 09:27:40
# 3  f88197465ea7920adcdbec7375364d82    delivered  13 days 05:00:36
# 4  8ab97904e6daea8866dbdbc4fb7aad2c    delivered   2 days 20:58:23
#
#    days_to_delivery day_of_week_purchase  time_purchase  \
# 0                 8               Monday             10
# ...

# %% [markdown]
# ## transformed_products + transformed_product_category_name

# %%
transformed_product_category_name.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
transformed_products.head()
# Out:
#                          product_id  product_category_name
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas

# %%
products_complet = pd.merge(
    left= transformed_products,
    right= transformed_product_category_name,
    on= 'product_category_name',
    how= 'left'
)

products_complet.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
products_complet.isna().mean().sort_values(ascending=False)
# Out:
# product_category_name_english    0.018907
# product_category_name            0.018512
# product_id                       0.000000
# dtype: float64

# %% [markdown]
# ## customers_orders + products_complet

# %%
customers_orders = pd.merge(
    left= customers_orders,
    right= products_complet[['product_id','product_category_name_english','product_category_name']],
    on= 'product_id',
    how= 'inner'
)

customers_orders.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 2  ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3  e781fdcc107d13d865fc7698711cc572  bfc39df4f36c3693ff3b63fcbea9e90a
# 4  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
#
#                         customer_id order_status  time_to_delivery  \
# 0  9ef432eb6251297304e76186b10a928d    delivered   8 days 10:28:40
# 1  a20e8105f23924cd00833fd87daa0831    delivered   2 days 20:15:12
# 2  26c7ac168e1433912a51b924fbd34d34    delivered   5 days 00:05:14
# 3  53904ddbea91e1e92b2b3f1d09a7af86    delivered  14 days 18:38:13
# 4  b0830fb4747a6c6d20dea0b8c802d7ef    delivered  13 days 18:46:08
#
#    days_to_delivery day_of_week_purchase  time_purchase  \
# 0                 8               Monday             10
# ...

# %%
customers_orders.shape
# Out:
# (112650, 16)

# %% [markdown]
# **Nan Values**

# %%
msk = (customers_orders["product_category_name"].notnull()) & (customers_orders['product_category_name_english'].isna())
customers_orders.loc[msk, "product_category_name"].unique()
# Out:
# array(['portateis_cozinha_e_preparadores_de_alimentos', 'pc_gamer'],
#       dtype=object)

# %%
msk = customers_orders['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos'
customers_orders.loc[msk, 'product_category_name_english']
# Out:
# 18618     NaN
# 54230     NaN
# 54231     NaN
# 54232     NaN
# 58246     NaN
# 62966     NaN
# 72554     NaN
# 72555     NaN
# 72556     NaN
# 82872     NaN
# 82873     NaN
# 103222    NaN
# 107664    NaN
# 111066    NaN
# 112407    NaN
# Name: product_category_name_english, dtype: object

# %%
msk = customers_orders['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos'
customers_orders.loc[msk, 'product_category_name_english'] = "portable_kitchen_food_preparation"

# %%
msk = customers_orders['product_category_name'] == 'pc_gamer'
customers_orders.loc[msk, 'product_category_name_english']
# Out:
# 30997     NaN
# 30998     NaN
# 30999     NaN
# 31000     NaN
# 31001     NaN
# 72634     NaN
# 107762    NaN
# 107763    NaN
# 107764    NaN
# Name: product_category_name_english, dtype: object

# %%
msk = customers_orders['product_category_name'] == 'pc_gamer'
customers_orders.loc[msk, 'product_category_name_english'] = 'pc_gamer'

# %% [markdown]
# **Reste des NaN : Uncategorized**

# %%
msk = (customers_orders['product_category_name'].isna()) & (customers_orders['product_category_name_english'].isna())
customers_orders.loc[msk, 'product_category_name_english'] = "Uncategorized"

# %%
msk = (customers_orders['product_category_name'].isna()) 
customers_orders.loc[msk, 'product_category_name'] = "Uncategorized"

# %%
customers_orders.isna().mean().sort_values(ascending=False) * 100
# Out:
# customer_unique_id               0.0
# order_id                         0.0
# customer_id                      0.0
# order_status                     0.0
# time_to_delivery                 0.0
# days_to_delivery                 0.0
# day_of_week_purchase             0.0
# time_purchase                    0.0
# estimated_days_to_delivery       0.0
# order_purchase_timestamp         0.0
# order_item_id                    0.0
# product_id                       0.0
# price                            0.0
# freight_value                    0.0
# product_category_name_english    0.0
# product_category_name            0.0
# dtype: float64

# %% [markdown]
# ## order_payments

# %%
transformed_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments = transformed_order_payments[[
    'order_id',
    'payment_installments',
    'payment_value'
]].groupby('order_id').sum().reset_index()

order_payments.head(5)
# Out:
#                            order_id  payment_installments  payment_value
# 0  00010242fe8c5a6d1ba2dd792cb16214                     2          72.19
# 1  00018f77f2f0320c557190d7a144bdd3                     3         259.83
# 2  000229ec398224ef6ca0657da4fc703e                     5         216.87
# 3  00024acbcdf0a6daa1e931b038114c75                     2          25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                     3         218.04

# %%
order_payments.shape
# Out:
# (99440, 3)

# %% [markdown]
# ## customers_orders + order_payments

# %%
customers_orders_payments = pd.merge(
    left= customers_orders,
    right= order_payments,
    on= 'order_id',
    how= 'left'
)

customers_orders_payments.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 2  ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3  e781fdcc107d13d865fc7698711cc572  bfc39df4f36c3693ff3b63fcbea9e90a
# 4  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
#
#                         customer_id order_status  time_to_delivery  \
# 0  9ef432eb6251297304e76186b10a928d    delivered   8 days 10:28:40
# 1  a20e8105f23924cd00833fd87daa0831    delivered   2 days 20:15:12
# 2  26c7ac168e1433912a51b924fbd34d34    delivered   5 days 00:05:14
# 3  53904ddbea91e1e92b2b3f1d09a7af86    delivered  14 days 18:38:13
# 4  b0830fb4747a6c6d20dea0b8c802d7ef    delivered  13 days 18:46:08
#
#    days_to_delivery day_of_week_purchase  time_purchase  \
# 0                 8               Monday             10
# ...

# %%
customers_orders_payments
# Out:
#                       customer_unique_id                          order_id  \
# 0       7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1       3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 2       ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3       e781fdcc107d13d865fc7698711cc572  bfc39df4f36c3693ff3b63fcbea9e90a
# 4       af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
# ...                                  ...                               ...
# 112645  fb9310710003399b031add3e55f34719  e8fd20068b9f7e6ec07068bb7537f781
# 112646  fb9310710003399b031add3e55f34719  e8fd20068b9f7e6ec07068bb7537f781
# 112647  a49e8e11e850592fe685ae3c64b40eca  cfa78b997e329a5295b4ee6972c02979
# 112648  6359f309b166b0196dbf7ad2ac62bb5a  9c5dedf39a927c1b2549525ed64a053c
# 112649  60350aa974b26ff12caad89e55993bd6  66dea50a8b16d9b4dee7af250b4be1a5
#
# ...

# %%
# Réduction du nombre de catégories : ce code est copié d'un projet kaggle

product_categories = {

    "fashion_bags_accessories": "fashion",    
    "fashio_female_clothing": "fashion",
    "fashion_sport": "fashion",
    "fashion_shoes": "fashion",
    "fashion_male_clothing": "fashion",   
    "fashion_underwear_beach": "fashion",
    "fashion_childrens_clothes": "fashion",
    "cool_stuff": "fashion",
    "art": "fashion",
    "arts_and_craftmanship": "fashion",
    "health_beauty": "fashion",
    "perfumery": "fashion",
    "watches_gifts": "fashion",
    
    'portable_kitchen_food_preparation' : "furniture",
    "kitchen_dining_laundry_garden_furniture": "furniture",
    "furniture_decor": "furniture",
    "office_furniture": "furniture", #ok
    "furniture_bedroom": "furniture",
    "furniture_living_room": "furniture",
    "furniture_mattress_and_upholstery": "furniture",
    "bed_bath_table": "furniture",

    
    "home_appliances": "home",
    "home_appliances_2": "home",
    "home_confort": "home", #ok
    "home_comfort_2": "home",
    "air_conditioning": "home",
    "housewares": "home", #ok
    "flowers": "home",
    
    
    "electronics": "electronics",
    "audio": "electronics",
    "tablets_printing_image": "electronics",
    "telephony": "electronics",
    "fixed_telephony": "electronics",
    "small_appliances": "electronics",
    "small_appliances_home_oven_and_coffee": "electronics",
    "computers_accessories": "electronics", #ok
    "computers": "electronics",
    "pc_gamer": "electronics",
    "consoles_games": "electronics",
    "dvds_blu_ray": "electronics",
    "portateis_cozinha_e_preparadores_de_alimentos": "electronics",
    
    
    "construction_tools_construction": "construction",
    "construction_tools_lights": "construction",
    "construction_tools_safety": "construction",
    "costruction_tools_garden": "construction",
    "costruction_tools_tools": "construction",
    "garden_tools": "construction",
    "home_construction": "construction",

    
    "sports_leisure": "sports_leisure", #ok
    "musical_instruments": "sports_leisure",
    "toys": "sports_leisure", #ok
    "cine_photo": "sports_leisure",
    "cds_dvds_musicals": "sports_leisure",
    "music": "sports_leisure",
    "books_general_interest": "sports_leisure",
    "books_imported": "sports_leisure",
    "books_technical": "sports_leisure",


    "christmas_supplies": "others",
    "stationery": "others",
    "party_supplies": "others",
    "auto": "others",
    "luggage_accessories": "others",
    "signaling_and_security": "others",
    "agro_industry_and_commerce": "others",
    "security_and_services": "others",
    "market_place": "others",
    "pet_shop": "others",    
    "industry_commerce_and_business": "others",  
    "baby": "others",
    "diapers_and_hygiene": "others",
    "drinks": "others",
    "food": "others",
    "food_drink": "others",
    "la_cuisine": "others",
    "unknown": "others",
    "Uncategorized" : "others"
}



customers_orders_payments["product_category"] = customers_orders_payments["product_category_name_english"].map(product_categories)

# %% [markdown]
# ## customers_orders_payments + transformed_order_reviews

# %%
customers_orders_payments = pd.merge(
    left= customers_orders_payments,
    right= transformed_order_reviews,
    on= 'order_id',
    how= 'left'
)

customers_orders_payments.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 2  ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3  e781fdcc107d13d865fc7698711cc572  bfc39df4f36c3693ff3b63fcbea9e90a
# 4  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
#
#                         customer_id order_status  time_to_delivery  \
# 0  9ef432eb6251297304e76186b10a928d    delivered   8 days 10:28:40
# 1  a20e8105f23924cd00833fd87daa0831    delivered   2 days 20:15:12
# 2  26c7ac168e1433912a51b924fbd34d34    delivered   5 days 00:05:14
# 3  53904ddbea91e1e92b2b3f1d09a7af86    delivered  14 days 18:38:13
# 4  b0830fb4747a6c6d20dea0b8c802d7ef    delivered  13 days 18:46:08
#
#    days_to_delivery day_of_week_purchase  time_purchase  \
# 0                 8               Monday             10
# ...

# %%
customers_orders_payments.isna().mean().sort_values(ascending=False)
# Out:
# review_score                     0.008362
# payment_value                    0.000027
# payment_installments             0.000027
# order_id                         0.000000
# product_category                 0.000000
# product_category_name            0.000000
# product_category_name_english    0.000000
# freight_value                    0.000000
# price                            0.000000
# product_id                       0.000000
# customer_unique_id               0.000000
# order_purchase_timestamp         0.000000
# estimated_days_to_delivery       0.000000
# time_purchase                    0.000000
# day_of_week_purchase             0.000000
# days_to_delivery                 0.000000
# time_to_delivery                 0.000000
# order_status                     0.000000
# customer_id                      0.000000
# order_item_id                    0.000000
# dtype: float64

# %%
msk = customers_orders_payments['payment_value'].isna()
customers_orders_payments.loc[msk, "payment_value"] = (customers_orders_payments.loc[msk, "price"] + customers_orders_payments.loc[msk, "freight_value"])

# %%
msk = customers_orders_payments['payment_installments'].isna()
customers_orders_payments.loc[msk, "payment_installments"] = 1

# %%
msk = customers_orders_payments['review_score'].isna()
customers_orders_payments.loc[msk, "review_score"] = customers_orders_payments['review_score'].fillna(customers_orders_payments.groupby('product_category')['review_score'].transform('median'))

# %%
customers_orders_payments.isna().mean().sort_values(ascending=False)
# Out:
# customer_unique_id               0.0
# order_id                         0.0
# product_category                 0.0
# payment_value                    0.0
# payment_installments             0.0
# product_category_name            0.0
# product_category_name_english    0.0
# freight_value                    0.0
# price                            0.0
# product_id                       0.0
# order_item_id                    0.0
# order_purchase_timestamp         0.0
# estimated_days_to_delivery       0.0
# time_purchase                    0.0
# day_of_week_purchase             0.0
# days_to_delivery                 0.0
# time_to_delivery                 0.0
# order_status                     0.0
# customer_id                      0.0
# review_score                     0.0
# dtype: float64

# %%
customers_orders_payments.head()
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 2  ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3  e781fdcc107d13d865fc7698711cc572  bfc39df4f36c3693ff3b63fcbea9e90a
# 4  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
#
#                         customer_id order_status  time_to_delivery  \
# 0  9ef432eb6251297304e76186b10a928d    delivered   8 days 10:28:40
# 1  a20e8105f23924cd00833fd87daa0831    delivered   2 days 20:15:12
# 2  26c7ac168e1433912a51b924fbd34d34    delivered   5 days 00:05:14
# 3  53904ddbea91e1e92b2b3f1d09a7af86    delivered  14 days 18:38:13
# 4  b0830fb4747a6c6d20dea0b8c802d7ef    delivered  13 days 18:46:08
#
#    days_to_delivery day_of_week_purchase  time_purchase  \
# 0                 8               Monday             10
# ...

# %% [markdown]
# ### Analyses graphiques

# %% [markdown]
# **order_status**

# %%
fig = plt.figure(figsize=(12, 6), dpi=200)
data_plot = customers_orders_payments['order_status']
sns.countplot(y=data_plot, order = customers_orders_payments['order_status'].value_counts(normalize=True).index, color='g')
plt.xticks(rotation=75);
plt.title('Nombre de commandes / order_status', fontsize=15)
plt.xlabel('Nombre de commandes', fontsize=15, fontweight='bold')
# Save Figure:
plt.savefig("figures/EDA/plot_10_customers_orders_payments_order_status.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# **day_of_week_purchase**

# %%
fig = plt.figure(figsize=(12, 6), dpi=200)
data_plot = customers_orders_payments['day_of_week_purchase']
sns.countplot(y=data_plot, order = customers_orders_payments['day_of_week_purchase'].value_counts(normalize=True).index, color='g')
plt.xticks(rotation=75);
plt.title('Nombre de commandes / day_of_week_purchase', fontsize=15)
plt.xlabel('Nombre de commandes', fontsize=15, fontweight='bold')
# Save Figure:
plt.savefig("figures/EDA/plot_11_customers_orders_payments_day_of_week_purchase.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# **product_category**

# %%
fig = plt.figure(figsize=(12, 6), dpi=200)
data_plot = customers_orders_payments['product_category']
sns.countplot(y=data_plot, order = customers_orders_payments['product_category'].value_counts(normalize=True).index, color='g')
plt.xticks(rotation=75);
plt.title('Nombre de commandes / product_category', fontsize=15)
plt.xlabel('Nombre de commandes', fontsize=15, fontweight='bold')
# Save Figure:
plt.savefig("figures/EDA/plot_12_customers_orders_payments_product_category.png", transparent=True, bbox_inches='tight', dpi=200)
plt.show()

# %% [markdown]
# **Distibution**

# %%
customers_orders_payments.columns
# Out:
# Index(['customer_unique_id', 'order_id', 'customer_id', 'order_status',
#        'time_to_delivery', 'days_to_delivery', 'day_of_week_purchase',
#        'time_purchase', 'estimated_days_to_delivery',
#        'order_purchase_timestamp', 'order_item_id', 'product_id', 'price',
#        'freight_value', 'product_category_name_english',
#        'product_category_name', 'payment_installments', 'payment_value',
#        'product_category', 'review_score'],
#       dtype='object')

# %%
customers_orders_payments.select_dtypes(exclude='O').columns
# Out:
# Index(['days_to_delivery', 'time_purchase', 'estimated_days_to_delivery',
#        'order_item_id', 'price', 'freight_value', 'payment_installments',
#        'payment_value', 'review_score'],
#       dtype='object')

# %%
# Distributions 
columns = customers_orders_payments.select_dtypes(exclude='O').columns
plot_distribution(customers_orders_payments, columns)

# %% [markdown]
# ## Save CSV : cleaned_customers_orders_payments_dataset

# %%
df = customers_orders_payments
path = "./data/cleaned/"
filename = "cleaned_customers_orders_payments_dataset.csv"
columns_to_save = list(customers_orders_payments.columns)

# Save
save_transformed_df(df, path, filename, columns_to_save)
